# %%
import ast
import glob
import warnings
from collections import defaultdict
from datetime import date

import numpy as np
import pandas as pd
import wandb

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import os
import json


today = date.today()
api = wandb.Api()

# # Find all csv files in the current directory
csv_files = glob.glob("csv/*.csv")
# # Collect all the names of the csv files without the extension
csv_names = [csv_file[:-4] for csv_file in csv_files]
project_name = "6g_4rd_September"  
user = "telyatnikov_sap"

if project_name not in csv_names:
    runs = api.runs(f"{user}/{project_name}")

    summary_list, config_list, name_list = [], [], []
    for run in runs:
        # .summary contains the output keys/values for metrics like accuracy.
        #  We call ._json_dict to omit large files
        summary_list.append(run.summary._json_dict)

        # .config contains the hyperparameters.
        #  We remove special values that start with _.
        config_list.append(
            {k: v for k, v in run.config.items() if not k.startswith("_")}
        )

        # .name is the human-readable name of the run.
        name_list.append(run.name)

    runs_df = pd.DataFrame(
        {"summary": summary_list, "config": config_list, "name": name_list}
    )

    runs_df.to_csv(f"csv/{user}_{project_name}.csv")
else:
    runs_df = pd.read_csv(f"csv/{user}_{project_name}.csv", index_col=0)

    for row in runs_df.iloc:
        row["summary"] = ast.literal_eval(row["summary"])
        row["config"] = ast.literal_eval(row["config"])


for row in runs_df.iloc:
    row["summary"].update(row["config"])

lst = [i["summary"] for i in runs_df.iloc]
df = pd.DataFrame.from_dict(lst)

df_init = df.copy()

# drop row 0
#df = df.drop(df.index[-1])

# %%
def normalize_column(df, column_to_normalize):
    # Use json_normalize to flatten the nested dictionaries into separate columns
    flattened_df = pd.json_normalize(df[column_to_normalize])
    # Rename columns to include 'nested_column' prefix
    flattened_df.columns = [
        f"{column_to_normalize}.{col}" for col in flattened_df.columns
    ]
    # Concatenate the flattened DataFrame with the original DataFrame
    result_df = pd.concat([df, flattened_df], axis=1)
    # Get new columns names
    new_columns = flattened_df.columns
    # Drop the original nested column if needed
    result_df.drop(column_to_normalize, axis=1, inplace=True)
    return result_df, new_columns


# Config columns to normalize
columns_to_normalize = ["decoder", 'compressor']
# df.fillna('NA', inplace=True)
# df = df[df['test/loss'] != 'NA']
# Keep track of config columns added
config_columns = []
for column in columns_to_normalize:
    df, columns = normalize_column(df, column)
    config_columns.extend(columns)



# substitute NaN with 'NA'
df.fillna('NA', inplace=True)
df = df[df['Elements compression'] != 'NA']
df = df[df['compressor.name'] != 'NA'] 
df['compressor.r'] = df['compressor.r'].apply(lambda x: str(x))
df['Elements compression'] = df['Elements compression'].apply(lambda x: np.round((1 - x)*100))
# Rename No Compression to VIT

# First rename conditional cases: 
df.loc[(df['compressor.name'] == 'AE') & (df['reconstruct_images'] == False), 'compressor.name'] = 'AC'


#df.loc[(df['compressor.name'] == 'Tome+AE')  & (df['compressor.r'] == '[0, 0, 0, 0, 0, 0]') & (df['reconstruct_images'] == False), 'compressor.name'] = 'VAC'
#df.loc[(df['compressor.name'] == 'Tome+AE')  & (df['compressor.r'] == '[0, 0, 0, 0, 0, 0]') & (df['reconstruct_images'] == True), 'compressor.name'] = 'VACR'

# Second rename conditional cases: 
df.loc[(df['compressor.name'] == 'Tome+AE') & (df['reconstruct_images'] == False), 'compressor.name'] = 'TAC'

df.loc[(df['compressor.name'] == 'Tome+AE') & (df['reconstruct_images'] == True), 'compressor.name'] = 'TACR'

# Baselines
df.loc[(df['compressor.name'] == 'Tome') & (df['compressor.r'] == '[0, 0, 0, 0, 0, 0]') & (df['reconstruct_images'] == False), 'compressor.name'] = 'VC'
df.loc[(df['compressor.name'] == 'Tome') & (df['compressor.r'] == '[0, 0, 0, 0, 0, 0]') & (df['reconstruct_images'] == True), 'compressor.name'] = 'VCR'





rename_dict = {
    'No Compression': 'VIT',
    'Tome':'TCR', 
    'AE':'ACR', 
    'Tome+onlyclassifier':'TC'
}

df['compressor.name'] = df['compressor.name'].apply(lambda x: rename_dict[x] if x in rename_dict else x)

# %%
# Why vcr is 4? 
df[df['compressor.name'] == 'TCR']
# Out:
#     Elements compression  Token compression     _runtime  _step    _timestamp  \
# 16                  95.0              0.051  1669.544933  24175  1.725852e+09
# 17                  88.0              0.117  1688.222002  24175  1.725850e+09
# 18                  15.0              0.847  2045.905703  24175  1.725848e+09
# 19                  95.0              0.051  1696.802124  24175  1.725846e+09
# 20                  88.0              0.117  1622.363263  24175  1.725844e+09
# 21                  15.0              0.847  2277.323987  24175  1.725843e+09
# 61                  95.0              0.051  2385.141423  24175  1.725593e+09
# 63                  88.0              0.117  2598.822671  24175  1.725591e+09
# 66                  31.0              0.694  3018.329048  24175  1.725588e+09
# 68                  15.0              0.847  3129.614052  24175  1.725585e+09
# 70                  95.0              0.051  1865.764664  24175  1.725582e+09
# 72                  88.0              0.117  1872.761658  24175  1.725580e+09
# 74                  31.0              0.694  2241.179024  24175  1.725578e+09
# 76                  15.0              0.847  2432.260430  24175  1.725576e+09
# 78                  95.0              0.051  2310.620288  24175  1.725574e+09
# 80                  88.0              0.117  2462.492686  24175  1.725571e+09
# 82                  31.0              0.694  2667.558224  24175  1.725564e+09
# 83                  15.0              0.847  2784.814693  24175  1.725562e+09
# 85                  95.0              0.051  1693.737263  24175  1.725559e+09
# 87                  88.0              0.117  1709.701585  24175  1.725557e+09
# 88                  31.0              0.694  1967.887342  24175  1.725555e+09
# 89                  15.0              0.847  2009.087207  24175  1.725553e+09
#
#                _wandb  test/accuracy  test/classification_loss test/loss  \
# 16  {'runtime': 1669}       0.850955                  0.540205  1.024173
# 17  {'runtime': 1688}       0.875414                  0.491440  0.892104
# 18  {'runtime': 2045}       0.878726                  0.542675  0.623972
# 19  {'runtime': 1696}       0.861401                  0.551544  1.011148
# 20  {'runtime': 1622}       0.875924                  0.501935  0.846558
# 21  {'runtime': 2277}       0.890446                  0.500155  0.567932
# 61  {'runtime': 2385}       0.849682                  0.559699       NaN
# 63  {'runtime': 2598}       0.867261                  0.502019       NaN
# 66  {'runtime': 3018}       0.880255                  0.493396  0.584057
# 68  {'runtime': 3129}       0.883567                  0.434232  0.524955
# 70  {'runtime': 1865}       0.844076                  0.633719  1.078229
# 72  {'runtime': 1872}       0.869299                  0.547662  0.940332
# 74  {'runtime': 2241}       0.878726                  0.489502  0.571851
# 76  {'runtime': 2432}       0.887898                  0.438655  0.511214
# 78  {'runtime': 2310}       0.856306                  0.565539       NaN
# 80  {'runtime': 2462}       0.869809                  0.452292       NaN
# 82  {'runtime': 2667}       0.881529                  0.571880  0.642707
# 83  {'runtime': 2784}       0.883822                  0.531224  0.599878
# 85  {'runtime': 1693}       0.861911                  0.553794  1.036978
# 87  {'runtime': 1709}       0.876433                  0.488496   0.83532
# 88  {'runtime': 1967}       0.882803                  0.573505  0.649719
# 89  {'runtime': 2009}       0.885096                  0.560415  0.624609
#
#     test/mse  ...  decoder.num_layers decoder.patch_size decoder.num_classes  \
# 16  0.483967  ...                  12                 16                  10
# 17  0.400664  ...                  12                 16                  10
# 18  0.081297  ...                  12                 16                  10
# 19  0.459604  ...                  12                 16                  10
# 20  0.344623  ...                  12                 16                  10
# 21  0.067777  ...                  12                 16                  10
# 61       NaN  ...                  12                 16                  10
# 63       NaN  ...                  12                 16                  10
# 66  0.090661  ...                  12                 16                  10
# 68  0.090724  ...                  12                 16                  10
# 70   0.44451  ...                  12                 16                  10
# 72   0.39267  ...                  12                 16                  10
# 74  0.082349  ...                  12                 16                  10
# 76  0.072559  ...                  12                 16                  10
# 78       NaN  ...                  12                 16                  10
# 80       NaN  ...                  12                 16                  10
# 82  0.070827  ...                  12                 16                  10
# 83  0.068654  ...                  12                 16                  10
# 85  0.483184  ...                  12                 16                  10
# 87  0.346823  ...                  12                 16                  10
# 88  0.076214  ...                  12                 16                  10
# 89  0.064194  ...                  12                 16                  10
#
#                       decoder.timm_pretrained_weights  \
# 16  [facebookresearch/deit:main, deit_tiny_patch16...
# 17  [facebookresearch/deit:main, deit_tiny_patch16...
# 18  [facebookresearch/deit:main, deit_tiny_patch16...
# 19  [facebookresearch/deit:main, deit_tiny_patch16...
# 20  [facebookresearch/deit:main, deit_tiny_patch16...
# 21  [facebookresearch/deit:main, deit_tiny_patch16...
# 61  [facebookresearch/deit:main, deit_tiny_patch16...
# 63  [facebookresearch/deit:main, deit_tiny_patch16...
# 66  [facebookresearch/deit:main, deit_tiny_patch16...
# 68  [facebookresearch/deit:main, deit_tiny_patch16...
# 70  [facebookresearch/deit:main, deit_tiny_patch16...
# 72  [facebookresearch/deit:main, deit_tiny_patch16...
# 74  [facebookresearch/deit:main, deit_tiny_patch16...
# 76  [facebookresearch/deit:main, deit_tiny_patch16...
# 78  [facebookresearch/deit:main, deit_tiny_patch16...
# 80  [facebookresearch/deit:main, deit_tiny_patch16...
# 82  [facebookresearch/deit:main, deit_tiny_patch16...
# 83  [facebookresearch/deit:main, deit_tiny_patch16...
# 85  [facebookresearch/deit:main, deit_tiny_patch16...
# 87  [facebookresearch/deit:main, deit_tiny_patch16...
# 88  [facebookresearch/deit:main, deit_tiny_patch16...
# 89  [facebookresearch/deit:main, deit_tiny_patch16...
#
#                 compressor.r  compressor.name  compressor.input_dim  \
# 16  [40, 40, 40, 40, 40, 40]              TCR                   192
# 17  [30, 30, 30, 30, 30, 30]              TCR                   192
# 18        [5, 5, 5, 5, 5, 5]              TCR                   192
# 19  [40, 40, 40, 40, 40, 40]              TCR                   192
# 20  [30, 30, 30, 30, 30, 30]              TCR                   192
# 21        [5, 5, 5, 5, 5, 5]              TCR                   192
# 61  [40, 40, 40, 40, 40, 40]              TCR                   192
# 63  [30, 30, 30, 30, 30, 30]              TCR                   192
# 66  [10, 10, 10, 10, 10, 10]              TCR                   192
# 68        [5, 5, 5, 5, 5, 5]              TCR                   192
# 70  [40, 40, 40, 40, 40, 40]              TCR                   192
# 72  [30, 30, 30, 30, 30, 30]              TCR                   192
# 74  [10, 10, 10, 10, 10, 10]              TCR                   192
# 76        [5, 5, 5, 5, 5, 5]              TCR                   192
# 78  [40, 40, 40, 40, 40, 40]              TCR                   192
# 80  [30, 30, 30, 30, 30, 30]              TCR                   192
# 82  [10, 10, 10, 10, 10, 10]              TCR                   192
# 83        [5, 5, 5, 5, 5, 5]              TCR                   192
# 85  [40, 40, 40, 40, 40, 40]              TCR                   192
# 87  [30, 30, 30, 30, 30, 30]              TCR                   192
# 88  [10, 10, 10, 10, 10, 10]              TCR                   192
# 89        [5, 5, 5, 5, 5, 5]              TCR                   192
#
#    compressor.activation  compressor.encoding_dim compressor.use_trace_loss
# 16                 False                      192                     False
# 17                 False                      192                     False
# 18                 False                      192                     False
# 19                 False                      192                     False
# 20                 False                      192                     False
# 21                 False                      192                     False
# 61                 False                      192                      True
# 63                 False                      192                      True
# 66                 False                      192                      True
# 68                 False                      192                      True
# 70                 False                      192                     False
# 72                 False                      192                     False
# 74                 False                      192                     False
# 76                 False                      192                     False
# 78                 False                      192                      True
# 80                 False                      192                      True
# 82                 False                      192                      True
# 83                 False                      192                      True
# 85                 False                      192                     False
# 87                 False                      192                     False
# 88                 False                      192                     False
# 89                 False                      192                     False
#
# [22 rows x 58 columns]

# %%
df[df['compressor.name'] == 'TCR'][['Elements compression', 'compressor.r', 'compressor.use_trace_loss']]
# Out:
#     Elements compression              compressor.r compressor.use_trace_loss
# 16                  95.0  [40, 40, 40, 40, 40, 40]                     False
# 17                  88.0  [30, 30, 30, 30, 30, 30]                     False
# 18                  15.0        [5, 5, 5, 5, 5, 5]                     False
# 19                  95.0  [40, 40, 40, 40, 40, 40]                     False
# 20                  88.0  [30, 30, 30, 30, 30, 30]                     False
# 21                  15.0        [5, 5, 5, 5, 5, 5]                     False
# 61                  95.0  [40, 40, 40, 40, 40, 40]                      True
# 63                  88.0  [30, 30, 30, 30, 30, 30]                      True
# 66                  31.0  [10, 10, 10, 10, 10, 10]                      True
# 68                  15.0        [5, 5, 5, 5, 5, 5]                      True
# 70                  95.0  [40, 40, 40, 40, 40, 40]                     False
# 72                  88.0  [30, 30, 30, 30, 30, 30]                     False
# 74                  31.0  [10, 10, 10, 10, 10, 10]                     False
# 76                  15.0        [5, 5, 5, 5, 5, 5]                     False
# 78                  95.0  [40, 40, 40, 40, 40, 40]                      True
# 80                  88.0  [30, 30, 30, 30, 30, 30]                      True
# 82                  31.0  [10, 10, 10, 10, 10, 10]                      True
# 83                  15.0        [5, 5, 5, 5, 5, 5]                      True
# 85                  95.0  [40, 40, 40, 40, 40, 40]                     False
# 87                  88.0  [30, 30, 30, 30, 30, 30]                     False
# 88                  31.0  [10, 10, 10, 10, 10, 10]                     False
# 89                  15.0        [5, 5, 5, 5, 5, 5]                     False

# %%
#df[(df['compressor.name'] == 'TCR') & (df['reconstruct_images'] == False)]

# %%
df['compressor.name'].unique()
# Out:
# array(['TAC', 'TACR', 'ACR', 'AC', 'TCR', 'VCR', 'VC', 'TC'], dtype=object)

# %%
# TODO
#df[(df['compressor.name'] == 'AE') & (df['reconstruct_images']==False)]

# %%
# drop row that have only 'NA'
df = df.dropna()

# %%
from collections import defaultdict

results = defaultdict(dict)
#df['model_type'].dropna(inplace=True)
#df[['model_type',  'decoder.use_trace_loss', 'Token compression', 'val/best_accuracy', 'validate_snr_db']]
df['model_type'] = df['model_type'].apply(lambda x: ' '.join(x.split('_')[-2:]))

# %%
# df.experiments_dir df.experiment_name
# Go over the rows and create path
new_col = []
for i, row in df.iterrows():
    new_col.append(f"{row['experiments_dir']}{row['experiment_name']}")

df['path'] = new_col

# %%
df['path']
# Out:
# 0     log/runs/2024-09-10-02-12-57
# 1     log/runs/2024-09-10-01-42-06
# 2     log/runs/2024-09-10-01-08-00
# 3     log/runs/2024-09-10-00-34-45
# 4     log/runs/2024-09-09-20-14-10
#                   ...
# 93    log/runs/2024-09-05-01-25-29
# 94    log/runs/2024-09-05-00-54-15
# 95    log/runs/2024-09-05-00-28-18
# 96    log/runs/2024-09-05-00-01-46
# 97    log/runs/2024-09-04-23-30-16
# Name: path, Length: 98, dtype: object

# %% [markdown]
# ### Main comrapison

# %%
df[(df['compressor.name']== 'TCR')& (df['compressor.r']=='[10, 10, 10, 10, 10, 10]')]['Elements compression']
# Out:
# 66    31.0
# 74    31.0
# 82    31.0
# 88    31.0
# Name: Elements compression, dtype: float64

# %%
df[(df['compressor.name']== 'TACR') &(df['compressor.use_trace_loss']== True)][['compressor.r','Elements compression', 'compressor.encoding_dim', 'train_snr_db']]
# Out:
#                 compressor.r  Elements compression  compressor.encoding_dim  \
# 42  [30, 30, 30, 30, 30, 30]                  89.0                      173
# 43        [5, 5, 5, 5, 5, 5]                  24.0                      173
# 44  [30, 30, 30, 30, 30, 30]                  92.0                      135
# 45        [5, 5, 5, 5, 5, 5]                  40.0                      135
# 46  [30, 30, 30, 30, 30, 30]                  89.0                      173
# 47        [5, 5, 5, 5, 5, 5]                  24.0                      173
# 48  [30, 30, 30, 30, 30, 30]                  92.0                      135
# 49        [5, 5, 5, 5, 5, 5]                  40.0                      135
#
#    train_snr_db
# 42       random
# 43       random
# 44       random
# 45       random
# 46            0
# 47            0
# 48            0
# 49            0

# %%
df[(df['compressor.name']== 'TC') &(df['compressor.use_trace_loss']== False)][['compressor.r','Elements compression', 'compressor.encoding_dim', 'train_snr_db']]
# Out:
#                 compressor.r  Elements compression  compressor.encoding_dim  \
# 84  [10, 10, 10, 10, 10, 10]                  31.0                      192
# 86  [10, 10, 10, 10, 10, 10]                  31.0                      192
# 90        [0, 0, 0, 0, 0, 0]                   0.0                      192
# 91        [0, 0, 0, 0, 0, 0]                   0.0                      192
# 92  [40, 40, 40, 40, 40, 40]                  95.0                      192
# 93  [30, 30, 30, 30, 30, 30]                  88.0                      192
# 94        [5, 5, 5, 5, 5, 5]                  15.0                      192
# 95  [40, 40, 40, 40, 40, 40]                  95.0                      192
# 96  [30, 30, 30, 30, 30, 30]                  88.0                      192
# 97        [5, 5, 5, 5, 5, 5]                  15.0                      192
#
#    train_snr_db
# 84       random
# 86            0
# 90       random
# 91            0
# 92       random
# 93       random
# 94       random
# 95            0
# 96            0
# 97            0

# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Shared and personalized sweep columns
shared_sweep_columns = [
    'compressor.name', 
    'train_classifier_separetely', 
    'train_snr_db', 
    'Elements compression'
]

personalised_sweep_columns = {
    'ACR':['compressor.encoding_dim'] + shared_sweep_columns,
    'AC':['compressor.encoding_dim'] + shared_sweep_columns,
    
    'TC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'VC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'TCR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'VCR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'TAC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'TACR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'VIT': shared_sweep_columns
}

# Filter conditions for each model
filter_conditions = {
    (0,0): {
        'VC': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },

        'AC': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
           'Elements compression': [ 15, 70,], #[ 15, 70, 88.],
        },


        'TC': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15., 31, 88.,], #[15., 88., 95.], 
            #'compressor.use_trace_loss': [True]
        },
       
        'TAC': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [ 40.,], #[24.0, 40.,],
            'compressor.use_trace_loss': [True],
    
        },
       
        },

    (0, 1): {

        'VC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },

        'AC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [ 15, 70,], #[ 15, 70,], #[ 15, 70, 88.],,
        },

        'TC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15., 31, 88.,], #[15., 88., 95.], 
            #'compressor.use_trace_loss': [True]
        },
        'TAC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
           'Elements compression': [ 40.,], #[24.0, 40.,],
            'compressor.use_trace_loss': [True],
        
        },
        
        },
    (1, 0): {
        'VCR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'compressor.use_trace_loss': [False]
        },
        'ACR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
           'Elements compression': [15., 70.,] #[15, 70, 88.]
        },
        'TCR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15., 88., 31.,], #[15., 88., 95.], 
            'compressor.use_trace_loss': [False],
        
        },
        'TACR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'compressor.use_trace_loss': [True],
            'Elements compression': [ 40.,],#[24.0, 40.,],
        },
    },
    (1, 1): {
        
        'VCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },

        'ACR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
           'Elements compression': [ 15., 70.,] #[ 15., 70., 88.]
        },

        'TCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15., 88., 31.,], #[15., 88., 95.], 
            'compressor.use_trace_loss': [False],
        
        },

        'TACR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [ 40.,], #[ 24.0, 40.,], 
            'compressor.use_trace_loss': [True],
        },

    }
}



# Line styles and markers for each model
line_styles = {
    'AC': 'solid',
    'VC': 'solid',
    "ACR": 'dashed', 
   
    "TC": 'solid', 
    "TCR": 'dashed',
    "VCR": 'dashed',

    "TAC": 'solid', 
    "TACR": 'dashed', 
}

markers = {
    "AC": 'o',
    "ACR": 'o',
    
    "TC": 'x', 
    "TCR": 'x', 

    "TAC": '^', 
    "TACR": '^',

    'VC': 'P',
    'VCR': 'P'  
}


# Plotting settings
settings = {
    'font.family': 'serif',
    'text.latex.preamble': '\\renewcommand{\\rmdefault}{ptm}\\renewcommand{\\sfdefault}{phv}',
    'figure.figsize': (20, 8),  # Adjusted figure size for two columns
    'figure.constrained_layout.use': True,
    'figure.autolayout': False,
    'font.size': 16,
    'axes.labelsize': 30,
    'legend.fontsize': 28,
    'xtick.labelsize': 28,
    'ytick.labelsize': 28,
    'axes.titlesize': 50
}
df_copy = df.copy()
with plt.rc_context(settings):
    fig, axs = plt.subplots(2, 2, figsize=(20, 10)) 
    final_legend_elements = []
    for ax_idx in filter_conditions.keys():
        ax = axs[ax_idx[0], ax_idx[1]]

        unique_combinations_collector = pd.DataFrame()
        ax_fc = filter_conditions[ax_idx]
        for compressor_name in ax_fc.keys():
            compressor_df = df.loc[df['compressor.name'] == compressor_name]
            sweep_columns = personalised_sweep_columns[compressor_name]
            unique_combinations = compressor_df[sweep_columns].drop_duplicates()

            # Filter according to conditions
            for condition, values in ax_fc[compressor_name].items():
                unique_combinations = unique_combinations.loc[unique_combinations[condition].isin(values)]

            unique_combinations_collector = pd.concat([unique_combinations_collector, unique_combinations])
        
        
        # Assign unique colors for each combination
        colors = plt.cm.tab10(np.linspace(0, 1, len(unique_combinations_collector) + 1))
        #color_dict = {idx: colors[i] for i, idx in enumerate(unique_combinations_collector.index)}
        color_dict = {idx: colors[i] for i, idx in enumerate(unique_combinations_collector.sort_values(by=['Elements compression', 'compressor.name']).index)}

        unique_combinations_collector.fillna('NA', inplace=True)

        
        for idx, combination in unique_combinations_collector.iterrows():
            selected_idx = [df_copy[key] == val for key, val in combination.items()]
            mask = np.logical_and.reduce(selected_idx)
            subset = df_copy[mask]
            
            if len(subset)>1:
                subset = df_copy[mask].loc[df_copy[mask].index[-1]]
                path_to_json = os.path.join(subset.path, 'results.json')
            else:   
                path_to_json = os.path.join(subset['path'].item(), 'results.json')

            # Load and plot results
            with open(path_to_json, 'r') as f:
                results = json.load(f)

            snr = np.array(list(results.keys())).astype(float)
            accuracy = np.array([results[key]['test/accuracy'] * 100 for key in results.keys()]).round(2)
            
            ax.plot(
                snr.astype(int),
                accuracy,
                marker=markers[combination['compressor.name']],
                color=color_dict[idx],
                linestyle=line_styles[combination['compressor.name']],
                lw=2,
                # make the likes a bit more transparent
                alpha=0.8,
                markersize=9,
            )

            # Create legend elements
            legend_elements = [
                Line2D(
                    [0], [0], 
                    color=color_dict[idx], 
                    lw=2, 
                    linestyle=line_styles[combination['compressor.name']], 
                    marker=markers[combination['compressor.name']],
                    markersize=10, 
                    


                    label=f"{combination['compressor.name']}, {int(combination['Elements compression'])}%"
                ) 
                for idx, combination in unique_combinations_collector.iterrows()
            ]

        if ax_idx == (0, 0) or ax_idx == (1,0):
            final_legend_elements += legend_elements
            # Add legends to the first subplot
           # ax.legend(handles=legend_elements, ncol=3, loc='lower right')
       
    
    # Set x-ticks to integer values and adjust labels for both subplots
    for row_idx, row in enumerate(axs):
        for ax_idx, ax in enumerate(row):
            
            if row_idx == 1:
                ax.set_xticks(snr.astype(int)[::2])
                ax.set_xlabel('SNR (db)', fontsize=30)
            else:
                ax.set_xticks([])
                # Add y-axis grid lines manually
                for xtick in snr.astype(int)[::2]:
                    ax.axvline(x=xtick, color='lightgray', linestyle='-', linewidth=1, zorder=0)

            ax.grid(True,  color='lightgray', linestyle='-', linewidth=1, zorder=0)

            if ax_idx == 0:
                ax.set_ylabel('Accuracy', fontsize=30)
            
            step = 1
            if row_idx == 0 and ax_idx == 0:
                left, right = 84, 91
                ax.set_ylim(left,  right-1)
                ax.set_yticks(np.arange(left, right, step))
                
            elif row_idx == 0 and ax_idx == 1: 
                left, right = 84, 91
                ax.set_ylim(left,  right-1)
                ax.set_yticks([])
                ax.grid(True, axis='y', linestyle='--')  # Force y-axis grid with custom linestyle
                # Add y-axis grid lines manually
                for ytick in np.arange(left,  right, step):
                    ax.axhline(y=ytick, color='lightgray', linestyle='-', linewidth=1, zorder=0)
        
            elif row_idx == 1 and ax_idx == 0:
                left, right = 79, 90
                ax.set_ylim(left,  right-1+0.2)
                ax.set_yticks(np.arange(left, right, step))

            elif row_idx == 1 and ax_idx == 1:
                left, right = 79, 90
                ax.set_ylim(left,  right-1+0.2)
                ax.set_yticks([])  # Remove y-ticks from the second and third subplots
                ax.grid(True, axis='y', linestyle='--')  # Force y-axis grid with custom linestyle

                # Add y-axis grid lines manually
                for ytick in np.arange(left,  right, step):
                    ax.axhline(y=ytick, color='lightgray', linestyle='-', linewidth=1, zorder=0)
            
            
    # Adjust spacing between subplots
    plt.subplots_adjust(wspace=3)  # Increase space between subplots
#plot legend on top of the figure 
#fig.legend(handles=final_legend_elements, ncol=8, loc=(0, 0.95), fontsize=17)
# increase legend size 
#fig.legend(handles=final_legend_elements, ncol=8, loc='upper center', fontsize=20)
# Adjust subplots to make room for the legend at the top
plt.subplots_adjust(top=0.82)  # Adjust top margin to leave space for the legend


fig.legend(handles=final_legend_elements, ncol=7, loc='upper center', bbox_to_anchor=(0.53, 1.08), fontsize=17)
# Place the legend at the top center of the figure
# out = []
# for i, j in zip(final_legend_elements[::2], final_legend_elements[1::2]):
#     out.append(i)
#     out.append(j)
# fig.legend(handles=out, ncol=7, loc='upper center', bbox_to_anchor=(0.53, 1.08), fontsize=17)

#fig.legend(handles=final_legend_elements[:10], ncol=5, loc='upper center', bbox_to_anchor=(0.29, 1.12), fontsize=18)
#fig.legend(handles=final_legend_elements[10:], ncol=5, loc='upper center', bbox_to_anchor=(0.77, 1.12), fontsize=18)



# Save and show plot
output_pdf_path = f"performance_plot.pdf"
plt.savefig(output_pdf_path, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_2414846/2233514471.py:331: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(wspace=3)  # Increase space between subplots
# /tmp/ipykernel_2414846/2233514471.py:337: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(top=0.82)  # Adjust top margin to leave space for the legend

# %%
unique_combinations_collector
# Out:
#    compressor.use_trace_loss              compressor.r  \
# 22                     False        [0, 0, 0, 0, 0, 0]
# 26                        NA                        NA
# 79                        NA                        NA
# 17                     False  [30, 30, 30, 30, 30, 30]
# 18                     False        [5, 5, 5, 5, 5, 5]
# 74                     False  [10, 10, 10, 10, 10, 10]
# 45                      True        [5, 5, 5, 5, 5, 5]
#
#     compressor.encoding_dim compressor.name  train_classifier_separetely  \
# 22                      192             VCR                        False
# 26                      163             ACR                        False
# 79                       58             ACR                        False
# 17                      192             TCR                        False
# 18                      192             TCR                        False
# 74                      192             TCR                        False
# 45                      135            TACR                        False
#
#    train_snr_db  Elements compression
# 22       random                   0.0
# 26       random                  15.0
# 79       random                  70.0
# 17       random                  88.0
# 18       random                  15.0
# 74       random                  31.0
# 45       random                  40.0

# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Shared and personalized sweep columns
shared_sweep_columns = [
    'compressor.name', 
    'train_classifier_separetely', 
    'train_snr_db', 
    'Elements compression'
]

personalised_sweep_columns = {
    'ACR':['compressor.encoding_dim'] + shared_sweep_columns,
    'AC':['compressor.encoding_dim'] + shared_sweep_columns,
    
    'TC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'VC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'TCR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'VCR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'TAC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'TACR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'VIT': shared_sweep_columns
}

# Filter conditions for each model
filter_conditions = {
    # (0,0): {
    #     'VC': {
    #         'train_snr_db': [0], 
    #         'train_classifier_separetely': [False], 
    #         #'Elements compression': [0.0], 
    #         'compressor.use_trace_loss': [False]
    #     },

    #     'AC': {
    #         'train_snr_db': [0], 
    #         'train_classifier_separetely': [False], 
    #        'Elements compression': [ 15, 70,], #[ 15, 70, 88.],
    #     },


    #     'TC': {
    #         'train_snr_db': [0], 
    #         'train_classifier_separetely': [False], 
    #         'Elements compression': [15., 31, 88.,], #[15., 88., 95.], 
    #         #'compressor.use_trace_loss': [True]
    #     },
       
    #     'TAC': {
    #         'train_snr_db': [0], 
    #         'train_classifier_separetely': [False], 
    #         'Elements compression': [ 40.,], #[24.0, 40.,],
    #         'compressor.use_trace_loss': [True],
    
    #     },
       
    #     },

    (0, 1): {

        'VC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },

        'AC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [ 15, 70,], #[ 15, 70,], #[ 15, 70, 88.],,
        },

        'TC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [15., 31, 88.,], #[15., 88., 95.], 
            #'compressor.use_trace_loss': [True]
        },
        'TAC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
           #'Elements compression': [ 40.,], #[24.0, 40.,],
           # 'compressor.use_trace_loss': [True],
        
        },
        
    #     },
    # (1, 0): {
    #     'VCR': {
    #         'train_snr_db': [0], 
    #         'train_classifier_separetely': [False], 
    #         'compressor.use_trace_loss': [False]
    #     },
    #     'ACR': {
    #         'train_snr_db': [0], 
    #         'train_classifier_separetely': [False], 
    #        'Elements compression': [15., 70.,] #[15, 70, 88.]
    #     },
    #     'TCR': {
    #         'train_snr_db': [0], 
    #         'train_classifier_separetely': [False], 
    #         'Elements compression': [15., 31, 88.,], #[15., 88., 95.], 
    #         'compressor.use_trace_loss': [False],
        
    #     },
    #     'TACR': {
    #         'train_snr_db': [0], 
    #         'train_classifier_separetely': [False], 
    #         'compressor.use_trace_loss': [True],
    #         'Elements compression': [ 40.,],#[24.0, 40.,],
    #     },
    # },
    # (1, 1): {
        
    #     'VCR': {
    #         'train_snr_db': ['random'], 
    #         'train_classifier_separetely': [False], 
    #         #'Elements compression': [0.0], 
    #         #'compressor.use_trace_loss': [False]
    #     },

    #     'ACR': {
    #         'train_snr_db': ['random'], 
    #         'train_classifier_separetely': [False], 
    #        #'Elements compression': [ 15., 70.,] #[ 15., 70., 88.]
    #     },

    #     'TCR': {
    #         'train_snr_db': ['random'], 
    #         'train_classifier_separetely': [False], 
    #         #'Elements compression': [15., 31, 88.,], #[15., 88., 95.], 
    #         #'compressor.use_trace_loss': [False],
        
    #     },

    #     'TACR': {
    #         'train_snr_db': ['random'], 
    #         'train_classifier_separetely': [False], 
    #         #'Elements compression': [ 40.,], #[ 24.0, 40.,], 
    #         #'compressor.use_trace_loss': [True],
    #     },

    }
}



# Line styles and markers for each model
line_styles = {
    'AC': 'solid',
    'VC': 'solid',
    "ACR": 'dashed', 
   
    "TC": 'solid', 
    "TCR": 'dashed',
    "VCR": 'dashed',

    "TAC": 'solid', 
    "TACR": 'dashed', 
}

markers = {
    "AC": 'o',
    "ACR": 'o',
    
    "TC": 'x', 
    "TCR": 'x', 

    "TAC": '^', 
    "TACR": '^',

    'VC': 'P',
    'VCR': 'P'  
}


# Plotting settings
settings = {
    'font.family': 'serif',
    'text.latex.preamble': '\\renewcommand{\\rmdefault}{ptm}\\renewcommand{\\sfdefault}{phv}',
    'figure.figsize': (20, 8),  # Adjusted figure size for two columns
    'figure.constrained_layout.use': True,
    'figure.autolayout': False,
    'font.size': 16,
    'axes.labelsize': 30,
    'legend.fontsize': 28,
    'xtick.labelsize': 28,
    'ytick.labelsize': 28,
    'axes.titlesize': 50
}
df_copy = df.copy()
fig, axs = plt.subplots(1, 1, figsize=(20, 10)) 
with plt.rc_context(settings):
    final_legend_elements = []
    for ax_idx in filter_conditions.keys():
        #ax = axs[ax_idx[0], ax_idx[1]]

        unique_combinations_collector = pd.DataFrame()
        ax_fc = filter_conditions[ax_idx]
        for compressor_name in ax_fc.keys():
            compressor_df = df.loc[df['compressor.name'] == compressor_name]
            sweep_columns = personalised_sweep_columns[compressor_name]
            unique_combinations = compressor_df[sweep_columns].drop_duplicates()

            # Filter according to conditions
            for condition, values in ax_fc[compressor_name].items():
                unique_combinations = unique_combinations.loc[unique_combinations[condition].isin(values)]

            unique_combinations_collector = pd.concat([unique_combinations_collector, unique_combinations])
        
        
        # Assign unique colors for each combination
        colors = plt.cm.tab10(np.linspace(0, 1, len(unique_combinations_collector) + 1))
        color_dict = {idx: colors[i] for i, idx in enumerate(unique_combinations_collector.index)}

        unique_combinations_collector.fillna('NA', inplace=True)
        model_compressions = defaultdict(dict)
        for idx, combination in unique_combinations_collector.iterrows():
            selected_idx = [df_copy[key] == val for key, val in combination.items()]
            mask = np.logical_and.reduce(selected_idx)
            subset = df_copy[mask]
            
            if len(subset)>1:
                subset = df_copy[mask].loc[df_copy[mask].index[-1]]
                path_to_json = os.path.join(subset.path, 'results.json')
            else:   
                path_to_json = os.path.join(subset['path'].item(), 'results.json')

            # Load and plot results
            with open(path_to_json, 'r') as f:
                results = json.load(f)

            
            
            snr = np.array(list(results.keys())).astype(float)
            accuracy = np.array([results[key]['test/accuracy'] * 100 for key in results.keys()]).round(2)
    
            model_compressions[combination['compressor.name']][subset['Elements compression'].item()] = accuracy[10]

    
        df_scatter = pd.DataFrame(model_compressions)
        df_scatter.fillna(np.nan, inplace=True)
        for column in df_scatter.columns:
            plt.scatter(df_scatter.index, df_scatter[column], 
                        label=column,
                        marker=markers[column],
                        s=100)
        plt.xlim(0, 100)
        plt.ylim(80, 90)

        # Adding labels and title
        plt.xlabel('X axis (0 to 100)')
        plt.ylabel('Y axis (70 to 90)')
        plt.title('Scatter Plot with NaN Handling')

        # Adding the legend
        plt.legend()

        # Display the plot
        plt.show()
            

# # Recreate the DataFrame based on the provided image
# data = {'VCR': [88.097619, np.nan, np.nan, np.nan, np.nan, np.nan],
#         'ACR': [np.nan, 84.338571, 83.941429, np.nan, np.nan, np.nan],
#         'TCR': [np.nan, 88.289524, np.nan, 86.420952, 87.566190, np.nan],
#         'TACR': [np.nan, np.nan, np.nan, np.nan, np.nan, 86.675238]}
# index = [0.0, 15.0, 70.0, 88.0, 31.0, 40.0]
# df = pd.DataFrame(data, index=index)

# # Create the scatter plot
# plt.figure(figsize=(10, 6))

# Iterate over each column in the DataFrame and plot non-NaN values


# Setting the x and y axis limits

        
        
        
        #     ax.plot(
        #         snr.astype(int),
        #         accuracy,
        #         marker=markers[combination['compressor.name']],
        #         color=color_dict[idx],
        #         linestyle=line_styles[combination['compressor.name']],
        #         lw=2,
        #         # make the likes a bit more transparent
        #         alpha=0.8,
        #         markersize=9,
        #     )

        #     # Create legend elements
        #     legend_elements = [
        #         Line2D(
        #             [0], [0], 
        #             color=color_dict[idx], 
        #             lw=2, 
        #             linestyle=line_styles[combination['compressor.name']], 
        #             marker=markers[combination['compressor.name']],
        #             markersize=10, 
        #             label=f"{combination['compressor.name']}, {int(combination['Elements compression'])}%"
        #         ) 
        #         for idx, combination in unique_combinations_collector.iterrows()
        #     ]

        # if ax_idx == (0, 0) or ax_idx == (1,0):
        #     final_legend_elements += legend_elements
        #     # Add legends to the first subplot
        #    # ax.legend(handles=legend_elements, ncol=3, loc='lower right')

    
#     # Set x-ticks to integer values and adjust labels for both subplots
#     for row_idx, row in enumerate(axs):
#         for ax_idx, ax in enumerate(row):
            
#             if row_idx == 1:
#                 ax.set_xticks(snr.astype(int)[::2])
#                 ax.set_xlabel('SNR (db)', fontsize=30)
#             else:
#                 ax.set_xticks([])
#                 # Add y-axis grid lines manually
#                 for xtick in snr.astype(int)[::2]:
#                     ax.axvline(x=xtick, color='lightgray', linestyle='-', linewidth=1, zorder=0)

#             ax.grid(True,  color='lightgray', linestyle='-', linewidth=1, zorder=0)

#             if ax_idx == 0:
#                 ax.set_ylabel('Accuracy', fontsize=30)
            
#             step = 1
#             if row_idx == 0 and ax_idx == 0:
#                 left, right = 84, 91
#                 ax.set_ylim(left,  right-1)
#                 ax.set_yticks(np.arange(left, right, step))
                
#             elif row_idx == 0 and ax_idx == 1: 
#                 left, right = 84, 91
#                 ax.set_ylim(left,  right-1)
#                 ax.set_yticks([])
#                 ax.grid(True, axis='y', linestyle='--')  # Force y-axis grid with custom linestyle
#                 # Add y-axis grid lines manually
#                 for ytick in np.arange(left,  right, step):
#                     ax.axhline(y=ytick, color='lightgray', linestyle='-', linewidth=1, zorder=0)
        
#             elif row_idx == 1 and ax_idx == 0:
#                 left, right = 79, 90
#                 ax.set_ylim(left,  right-1+0.2)
#                 ax.set_yticks(np.arange(left, right, step))

#             elif row_idx == 1 and ax_idx == 1:
#                 left, right = 79, 90
#                 ax.set_ylim(left,  right-1+0.2)
#                 ax.set_yticks([])  # Remove y-ticks from the second and third subplots
#                 ax.grid(True, axis='y', linestyle='--')  # Force y-axis grid with custom linestyle

#                 # Add y-axis grid lines manually
#                 for ytick in np.arange(left,  right, step):
#                     ax.axhline(y=ytick, color='lightgray', linestyle='-', linewidth=1, zorder=0)
            
            
#     # Adjust spacing between subplots
#     plt.subplots_adjust(wspace=3)  # Increase space between subplots
# #plot legend on top of the figure 
# #fig.legend(handles=final_legend_elements, ncol=8, loc=(0, 0.95), fontsize=17)
# # increase legend size 
# #fig.legend(handles=final_legend_elements, ncol=8, loc='upper center', fontsize=20)
# # Adjust subplots to make room for the legend at the top
# plt.subplots_adjust(top=0.82)  # Adjust top margin to leave space for the legend

# # Place the legend at the top center of the figure
# fig.legend(handles=final_legend_elements, ncol=9, loc='upper center', bbox_to_anchor=(0.53, 1.1), fontsize=17)
# #fig.legend(handles=final_legend_elements[:10], ncol=5, loc='upper center', bbox_to_anchor=(0.29, 1.12), fontsize=18)
# #fig.legend(handles=final_legend_elements[10:], ncol=5, loc='upper center', bbox_to_anchor=(0.77, 1.12), fontsize=18)



# # Save and show plot
# output_pdf_path = f"performance_plot.pdf"
# plt.savefig(output_pdf_path, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ### New plot

# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Shared and personalized sweep columns
shared_sweep_columns = [
    'compressor.name', 
    'train_classifier_separetely', 
    'train_snr_db', 
    'Elements compression'
]

personalised_sweep_columns = {
    'ACR':['compressor.encoding_dim'] + shared_sweep_columns,
    'AC':['compressor.encoding_dim'] + shared_sweep_columns,
    
    'TC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'VC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'TCR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'VCR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'TAC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'TACR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'VIT': shared_sweep_columns
}

# Filter conditions for each model
filter_conditions = {
    (0,0): {
        'AC': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
           'Elements compression': [70, 30]
        },


        'TC': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15., 88.,], #[15., 88., 95.], 
            #'compressor.use_trace_loss': [True]
        },
       
        'TAC': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [92., 40.],
    
        },

        'VC': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },

        
       
        },

    (0, 1): {
        'AC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [70, 30],
        },

        'TC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15., 88.,], #[15., 88., 95.], 
            #'compressor.use_trace_loss': [True]
        },
        'TAC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
           'Elements compression': [92., 40.],
            'compressor.use_trace_loss': [True],
        
        },
        'VC': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },
        
        },
    (1, 0): {
        'ACR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
           'Elements compression': [70, 30]
        },
        'TCR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15., 88.,], #[15., 88., 95.], 
            'compressor.use_trace_loss': [False],
        
        },

        'TACR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'compressor.use_trace_loss': [True],
            'Elements compression': [92., 40.],
        },
        'VCR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },
    },
    (1, 1): {
        'ACR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
           'Elements compression': [70, 30]
        },
        'TCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15., 88.,], #[15., 88., 95.], 
            'compressor.use_trace_loss': [False],
        
        },

        'TACR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [92., 40.], 
            'compressor.use_trace_loss': [True],
        },
        'VCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },

    }
}



# Line styles and markers for each model
line_styles = {
    'AC': 'solid',
    'VC': 'solid',
    "ACR": 'dashed', 
   
    "TC": 'solid', 
    "TCR": 'dashed',
    "VCR": 'dashed',

    "TAC": 'solid', 
    "TACR": 'dashed', 
}

markers = {
    "AC": 'o',
    "ACR": 'o',
    
    "TC": 'x', 
    "TCR": 'x', 

    "TAC": '^', 
    "TACR": '^',

    'VC': 'P',
    'VCR': 'P'  
}


# Plotting settings
settings = {
    'font.family': 'serif',
    'text.latex.preamble': '\\renewcommand{\\rmdefault}{ptm}\\renewcommand{\\sfdefault}{phv}',
    'figure.figsize': (20, 8),  # Adjusted figure size for two columns
    'figure.constrained_layout.use': True,
    'figure.autolayout': False,
    'font.size': 16,
    'axes.labelsize': 30,
    'legend.fontsize': 28,
    'xtick.labelsize': 28,
    'ytick.labelsize': 28,
    'axes.titlesize': 50
}
df_copy = df.copy()
with plt.rc_context(settings):
    fig, axs = plt.subplots(2, 2, figsize=(20, 10)) 
    final_legend_elements = []
    for ax_idx in filter_conditions.keys():
        ax = axs[ax_idx[0], ax_idx[1]]

        unique_combinations_collector = pd.DataFrame()
        ax_fc = filter_conditions[ax_idx]
        for compressor_name in ax_fc.keys():
            compressor_df = df.loc[df['compressor.name'] == compressor_name]
            sweep_columns = personalised_sweep_columns[compressor_name]
            unique_combinations = compressor_df[sweep_columns].drop_duplicates()

            # Filter according to conditions
            for condition, values in ax_fc[compressor_name].items():
                unique_combinations = unique_combinations.loc[unique_combinations[condition].isin(values)]

            unique_combinations_collector = pd.concat([unique_combinations_collector, unique_combinations])
        
        
        # Assign unique colors for each combination
        colors = plt.cm.tab10(np.linspace(0, 1, len(unique_combinations_collector) + 1))
        #color_dict = {idx: colors[i] for i, idx in enumerate(unique_combinations_collector.index)}
        color_dict = {idx: colors[i] for i, idx in enumerate(unique_combinations_collector.sort_values(by=['Elements compression', 'compressor.name']).index)}

        unique_combinations_collector.fillna('NA', inplace=True)

        
        for idx, combination in unique_combinations_collector.iterrows():
            selected_idx = [df_copy[key] == val for key, val in combination.items()]
            mask = np.logical_and.reduce(selected_idx)
            subset = df_copy[mask]
            
            if len(subset)>1:
                subset = df_copy[mask].loc[df_copy[mask].index[-1]]
                path_to_json = os.path.join(subset.path, 'results.json')
            else:   
                path_to_json = os.path.join(subset['path'].item(), 'results.json')

            # Load and plot results
            with open(path_to_json, 'r') as f:
                results = json.load(f)

            snr = np.array(list(results.keys())).astype(float)
            accuracy = np.array([results[key]['test/accuracy'] * 100 for key in results.keys()]).round(2)
            
            ax.plot(
                snr.astype(int),
                accuracy,
                marker=markers[combination['compressor.name']],
                color=color_dict[idx],
                linestyle=line_styles[combination['compressor.name']],
                lw=2,
                # make the likes a bit more transparent
                alpha=0.8,
                markersize=9,
            )

            # Create legend elements
            legend_elements = [
                Line2D(
                    [0], [0], 
                    color=color_dict[idx], 
                    lw=2, 
                    linestyle=line_styles[combination['compressor.name']], 
                    marker=markers[combination['compressor.name']],
                    markersize=10, 
                    label=f"{combination['compressor.name']}, {int(combination['Elements compression'])}%"
                ) 
                for idx, combination in unique_combinations_collector.iterrows()
            ]

        if ax_idx == (0, 0) or ax_idx == (1,0):
            final_legend_elements += legend_elements
            # Add legends to the first subplot
           # ax.legend(handles=legend_elements, ncol=3, loc='lower right')
       
    
    # Set x-ticks to integer values and adjust labels for both subplots
    for row_idx, row in enumerate(axs):
        for ax_idx, ax in enumerate(row):
            
            if row_idx == 1:
                ax.set_xticks(snr.astype(int)[::2])
                ax.set_xlabel('SNR (db)', fontsize=30)
            else:
                ax.set_xticks([])
                # Add y-axis grid lines manually
                for xtick in snr.astype(int)[::2]:
                    ax.axvline(x=xtick, color='lightgray', linestyle='-', linewidth=1, zorder=0)

            ax.grid(True,  color='lightgray', linestyle='-', linewidth=1, zorder=0)

            if ax_idx == 0:
                ax.set_ylabel('Accuracy', fontsize=30)
            
            step = 1
            if row_idx == 0 and ax_idx == 0:
                left, right = 84, 91
                ax.set_ylim(left,  right-1)
                ax.set_yticks(np.arange(left, right, step))
                
            elif row_idx == 0 and ax_idx == 1: 
                left, right = 84, 91
                ax.set_ylim(left,  right-1)
                ax.set_yticks([])
                ax.grid(True, axis='y', linestyle='--')  # Force y-axis grid with custom linestyle
                # Add y-axis grid lines manually
                for ytick in np.arange(left,  right, step):
                    ax.axhline(y=ytick, color='lightgray', linestyle='-', linewidth=1, zorder=0)
        
            elif row_idx == 1 and ax_idx == 0:
                left, right = 79, 90.5
                ax.set_ylim(left,  right-1)
                ax.set_yticks(np.arange(left, right, step))

            elif row_idx == 1 and ax_idx == 1:
                left, right = 79, 90.5
                ax.set_ylim(left,  right-1)
                ax.set_yticks([])  # Remove y-ticks from the second and third subplots
                ax.grid(True, axis='y', linestyle='--')  # Force y-axis grid with custom linestyle

                # Add y-axis grid lines manually
                for ytick in np.arange(left,  right, step):
                    ax.axhline(y=ytick, color='lightgray', linestyle='-', linewidth=1, zorder=0)
            
            
    # Adjust spacing between subplots
    plt.subplots_adjust(wspace=3)  # Increase space between subplots
#plot legend on top of the figure 
#fig.legend(handles=final_legend_elements, ncol=8, loc=(0, 0.95), fontsize=17)
# increase legend size 
#fig.legend(handles=final_legend_elements, ncol=8, loc='upper center', fontsize=20)
# Adjust subplots to make room for the legend at the top
plt.subplots_adjust(top=0.85)  # Adjust top margin to leave space for the legend

# Place the legend at the top center of the figure
fig.legend(handles=final_legend_elements, ncol=8, loc='upper center', bbox_to_anchor=(0.5, 1.1), fontsize=18)



# Save and show plot
output_pdf_path = f"performance_plot.pdf"
plt.savefig(output_pdf_path, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_2388656/932043363.py:326: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(wspace=3)  # Increase space between subplots
# /tmp/ipykernel_2388656/932043363.py:332: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(top=0.85)  # Adjust top margin to leave space for the legend

# %% [markdown]
# ### Table

# %%
# Shared and personalized sweep columns
shared_sweep_columns = [
    'compressor.name', 
    'train_classifier_separetely', 
    'train_snr_db', 
    'Elements compression'
]

personalised_sweep_columns = {
    'ACR':['compressor.encoding_dim'] + shared_sweep_columns,
    'AC':['compressor.encoding_dim'] + shared_sweep_columns,
    
    'TC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'VC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'TCR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'VCR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'TAC': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,
    'TACR': ['compressor.use_trace_loss', 'compressor.r', 'compressor.encoding_dim'] + shared_sweep_columns,

    'VIT': shared_sweep_columns
}



# Filter conditions for each model
filter_conditions = {
    0: {

        'VCR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },
        'ACR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
           'Elements compression': [15., 30., 70.,]
        },

         'TCR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [ 15., 31, 88.], 
            'compressor.use_trace_loss': [False],
        },
       
        'TACR': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [40.], 
            'compressor.use_trace_loss': [False],
        
        },
        
        },
    1: {
        'VCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [0.0], 
            'compressor.use_trace_loss': [False]
        },

        'ACR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15, 30., 70],
        },

        'TCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [ 15., 31., 88.,], 
            'compressor.use_trace_loss': [False],
        
        },

        'TACR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [40.], 
            'compressor.use_trace_loss': [False],
        
        },
        
        },
}



df_copy = df.copy()

num_plots = 2

unique_combinations_collector = pd.DataFrame()
for ax_idx in range(num_plots):
    #ax = axs[ax_idx]

    ax_fc = filter_conditions[ax_idx]
    for compressor_name in ax_fc.keys():
        compressor_df = df.loc[df['compressor.name'] == compressor_name]
        sweep_columns = personalised_sweep_columns[compressor_name]
        unique_combinations = compressor_df[sweep_columns].drop_duplicates()

        # Filter according to conditions
        for condition, values in ax_fc[compressor_name].items():
            unique_combinations = unique_combinations.loc[unique_combinations[condition].isin(values)]

        unique_combinations_collector = pd.concat([unique_combinations_collector, unique_combinations])
    
    # Assign unique colors for each combination
    colors = plt.cm.tab10(np.linspace(0, 1, len(unique_combinations_collector) + 1))
    color_dict = {idx: colors[i] for i, idx in enumerate(unique_combinations_collector.index)}

    unique_combinations_collector.fillna('NA', inplace=True)

    unique_combinations_collector[unique_combinations_collector['compressor.name'].isin(['TVIT'])]


#snr_vals_to_keep = [-10, 0, 10]
new_df = []
for idx, combination in unique_combinations_collector.iterrows():
    selected_idx = [df_copy[key] == val for key, val in combination.items()]
    mask = np.logical_and.reduce(selected_idx)
    subset = df_copy[mask]

    if len(subset)>1:
        subset = df_copy[mask].loc[df_copy[mask].index[-1]]
        path_to_json = os.path.join(subset.path, 'results.json')
    else:   
        path_to_json = os.path.join(subset['path'].item(), 'results.json')

    # Load and plot results
    with open(path_to_json, 'r') as f:
        results = json.load(f)

    snr = np.array(list(results.keys())).astype(float)
    mse = np.array([results[key]['test/mse'] * 100 for key in results.keys()]).round(2)

    #for s,m in zip(snr, mse):
        # if (s == 0) or (s == -5) or (s == 5):
        #     new_df.append({
        #                 'snr': s, 
        #                 'mse': m,
        #                 'Model': combination['compressor.name'] + " " + str(int(combination['Elements compression'])) + '%', 
        #                 'Elements compression': combination['Elements compression'],  # Add a comma here
        #                 'train_snr_db': 'Noise' if combination['train_snr_db']=='random' else 'No Noise',

        #             })
    new_df.append({
                'snr': 'mean', 
                'mse': np.mean(np.sqrt(mse[:])).round(2),# 5:15
                'std': np.std(np.sqrt(mse[:])).round(2),
                'Model': combination['compressor.name'] + " " + str(int(combination['Elements compression'])) + '%', 
                'Elements compression': combination['Elements compression'],  # Add a comma here
                'train_snr_db': 'Noise' if combination['train_snr_db']=='random' else 'No Noise', })

    
new_df = pd.DataFrame(new_df)
#new_df['accuracy'] = new_df['accuracy_mean'].astype(str) + ' ± ' + new_df['accuracy_std'].astype(str)

#Create a pivot table and consider to have accuracy_mean +- accuracy_std
pivot_df_mean = new_df.pivot_table(
index=['Model'], 
columns=['train_snr_db', 'snr'], 
values='mse'
)

pivot_df_std = new_df.pivot_table(
index=['Model'], 
columns=['train_snr_db', 'snr'], 
values='std'
)

# %%
a = pivot_df_mean.loc[['VCR 0%', 'ACR 15%', 'ACR 30%', 'TCR 15%', 'TCR 31%', 'TACR 40%']].T

# %%
b = pivot_df_std.loc[['VCR 0%', 'ACR 15%', 'ACR 30%', 'TCR 15%', 'TCR 31%', 'TACR 40%']].T

# combine datafrranes a nd b such that a \pm b

c = a.astype(str) + ' ± ' + b.astype(str)

# %%
print(c.to_latex())
# Out:
# \begin{tabular}{llllllll}
# \toprule
#  & Model & VCR 0% & ACR 15% & ACR 30% & TCR 15% & TCR 31% & TACR 40% \\
# train_snr_db & snr &  &  &  &  &  &  \\
# \midrule
# No Noise & mean & 3.68 ± 1.52 & 3.88 ± 1.15 & 3.98 ± 1.34 & 3.75 ± 1.47 & 3.85 ± 1.34 & 3.96 ± 1.25 \\
# \cline{1-8}
# Noise & mean & 3.72 ± 0.7 & 3.85 ± 0.73 & 4.02 ± 0.82 & 3.53 ± 0.79 & 3.64 ± 0.74 & 3.98 ± 0.73 \\
# \cline{1-8}
# \bottomrule
# \end{tabular}

# %%
new_df
# Out:
#      snr   mse       std     Model  Elements compression train_snr_db
# 0   mean  3.19  0.563242    VCR 0%                   0.0     No Noise
# 1   mean  3.52  0.419994   ACR 15%                  15.0     No Noise
# 2   mean  3.55  0.478544   ACR 30%                  30.0     No Noise
# 3   mean  4.32  0.589953   ACR 70%                  70.0     No Noise
# 4   mean  6.08  0.142269   TCR 88%                  88.0     No Noise
# 5   mean  3.27  0.550552   TCR 15%                  15.0     No Noise
# 6   mean  3.41  0.482181   TCR 31%                  31.0     No Noise
# 7   mean  3.54  0.413889  TACR 40%                  40.0     No Noise
# 8   mean  3.58  0.298574    VCR 0%                   0.0        Noise
# 9   mean  3.68  0.304668   ACR 15%                  15.0        Noise
# 10  mean  3.83  0.335816   ACR 30%                  30.0        Noise
# 11  mean  4.39  0.463735   ACR 70%                  70.0        Noise
# 12  mean  6.41  0.087873   TCR 88%                  88.0        Noise
# 13  mean  3.38  0.337035   TCR 15%                  15.0        Noise
# 14  mean  3.49  0.308886   TCR 31%                  31.0        Noise
# 15  mean  3.79  0.290404  TACR 40%                  40.0        Noise

# %%
unique_combinations_collector
# Out:
#     compressor.encoding_dim compressor.name  train_classifier_separetely  \
# 39                      135             ACR                        False
# 55                       58             ACR                        False
# 59                      192             TCR                        False
# 61                      192             TCR                        False
# 63                      192             TCR                        False
# 38                      135             ACR                        False
# 53                       58             ACR                        False
# 44                      192             TCR                        False
# 46                      192             TCR                        False
# 50                      192             TCR                        False
#
#    train_snr_db  Elements compression compressor.use_trace_loss  \
# 39            0                  30.0                        NA
# 55            0                  70.0                        NA
# 59            0                  95.0                     False
# 61            0                  88.0                     False
# 63            0                  15.0                     False
# 38       random                  30.0                        NA
# 53       random                  70.0                        NA
# 44       random                  95.0                     False
# 46       random                  88.0                     False
# 50       random                  15.0                     False
#
#                 compressor.r
# 39                        NA
# 55                        NA
# 59  [40, 40, 40, 40, 40, 40]
# 61  [30, 30, 30, 30, 30, 30]
# 63        [5, 5, 5, 5, 5, 5]
# 38                        NA
# 53                        NA
# 44  [40, 40, 40, 40, 40, 40]
# 46  [30, 30, 30, 30, 30, 30]
# 50        [5, 5, 5, 5, 5, 5]

# %%
new_df
# Out:
#     snr    mse compressor.name  Elements compression train_snr_db
# 0     0  11.14             ACR                  30.0      NoNoise
# 1     0  16.42             ACR                  70.0      NoNoise
# 2     0    NaN             TCR                  95.0      NoNoise
# 3     0    NaN             TCR                  88.0      NoNoise
# 4     0  10.03             TCR                  15.0      NoNoise
# 5     0    NaN            TACR                  92.0      NoNoise
# 6     0  12.76            TACR                  40.0      NoNoise
# 7     0  13.70             ACR                  30.0        Noise
# 8     0  17.87             ACR                  70.0        Noise
# 9     0    NaN             TCR                  95.0        Noise
# 10    0    NaN             TCR                  88.0        Noise
# 11    0  13.24             TCR                  15.0        Noise
# 12    0    NaN            TACR                  92.0        Noise
# 13    0  13.29            TACR                  40.0        Noise

# %%
pivot_df_mean
# Out:
# train_snr_db          NoNoise  Noise
# Elements compression
# 15.0                    17.52  16.01
# 30.0                    17.68  16.83
# 40.0                    19.21  16.29
# 70.0                    26.44  22.68

# %%
new_df
# Out:
#        snr  mse_mean  mse_std compressor.name  Elements compression  \
# 0  Average     16.83     7.26             ACR                  30.0
# 1  Average     22.68    11.49             ACR                  70.0
# 2  Average       NaN      NaN             TCR                  95.0
# 3  Average       NaN      NaN             TCR                  88.0
# 4  Average     16.01     7.13             TCR                  15.0
# 5  Average       NaN      NaN            TACR                  92.0
# 6  Average     16.29     7.20            TACR                  40.0
#
#   train_snr_db
# 0        Noise
# 1        Noise
# 2        Noise
# 3        Noise
# 4        Noise
# 5        Noise
# 6        Noise

# %%
df[(df['compressor.name'] =='TAC')&(df['train_snr_db'] == 'random')]['compressor.encoding_dim']
# Out:
# 0    135
# Name: compressor.encoding_dim, dtype: int64

# %%
import glob 
path_to_images_collector = None
path_to_images=None
filter_conditions = {
    0: {
        'TCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [ 15.], 
            'compressor.use_trace_loss': [False]
        },       
        },
    1: {
        'TCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [31.,], 
           'compressor.use_trace_loss': [False],
        },
    },
    2: {
        'TCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [88.,], 
           'compressor.use_trace_loss': [False],
        },
    },

3: {
        'TCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [ 15.], 
            'compressor.use_trace_loss': [False]
        },       
        },
4: {
        'TCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [31.,], 
           'compressor.use_trace_loss': [False],
        },
    },
5: {
        'TCR': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [88.,], 
           'compressor.use_trace_loss': [False],
        },
    },

}


num_plots = len(filter_conditions)
df_copy = df.copy()
path_to_images_collector = {}
for ax_idx in range(num_plots):
#    ax = axs[ax_idx]

    unique_combinations_collector = pd.DataFrame()
    ax_fc = filter_conditions[ax_idx]
    for compressor_name in ax_fc.keys():
        compressor_df = df.loc[df['compressor.name'] == compressor_name]
        sweep_columns = personalised_sweep_columns[compressor_name]
        unique_combinations = compressor_df[sweep_columns].drop_duplicates()

        # Filter according to conditions
        for condition, values in ax_fc[compressor_name].items():
            unique_combinations = unique_combinations.loc[unique_combinations[condition].isin(values)]

        unique_combinations_collector = pd.concat([unique_combinations_collector, unique_combinations])
    
    
    # Assign unique colors for each combination
    colors = plt.cm.tab10(np.linspace(0, 1, len(unique_combinations_collector) + 1))
    color_dict = {idx: colors[i] for i, idx in enumerate(unique_combinations_collector.index)}

    unique_combinations_collector.fillna('NA', inplace=True)

    
    for idx, combination in unique_combinations_collector.iterrows():
        selected_idx = [df_copy[key] == val for key, val in combination.items()]
        mask = np.logical_and.reduce(selected_idx)
        subset = df_copy[mask]

        if len(subset)>1:
            subset = df_copy[mask].loc[df_copy[mask].index[-1]]
            path_to_images = os.path.join(subset['path'], 'images/epoch_best/reconstructed/0/pergroup')
        else:   
            path_to_images = os.path.join(subset['path'].item(), 'images/epoch_best/reconstructed/0/pergroup')

        


        paths_to_images = glob.glob(path_to_images+'/*.png')
        idx = np.array([int(img.split('/')[-1].split('.')[0].split('_')[-1]) for img in paths_to_images]).argsort()
        paths_to_images = np.array(paths_to_images)[idx]
    
    path_to_images_collector[ax_idx] = paths_to_images


for i in path_to_images_collector.keys():
    path_to_images_collector[i] = path_to_images_collector[i][-1]#[2::3]


num_images = 2
new_path_to_images_collector = {0:[], 1:[]}
for row_key in range(num_images):
    if row_key == 0:
        for key in [0,1,2]:
            new_path_to_images_collector[row_key].append(path_to_images_collector[key])
    else:
        for key in [3,4,5]:
            new_path_to_images_collector[row_key].append(path_to_images_collector[key])
    
path_to_images_collector = new_path_to_images_collector




import matplotlib.pyplot as plt
from PIL import Image

def load_images(image_paths):
    """Load images from given paths and convert to RGB."""
    images = []
    for path in image_paths:
        img = Image.open(path)
        if img.mode != 'RGB':
            img = img.convert('RGB')
        images.append(img)
    return images

# Example code assuming path_to_images_collector is a dictionary
# with lists of image paths for keys 0 and 1.
for i in path_to_images_collector.keys():
    path_to_images_collector[i] = load_images(path_to_images_collector[i])
# path_to_images_collector[0] = load_images(path_to_images_collector[0])
# path_to_images_collector[1] = load_images(path_to_images_collector[1])

# Number of images
total_images = len(path_to_images_collector[0])

# Create a new figure with two rows and total_images columns
fig, axes = plt.subplots(
    len(path_to_images_collector),
    total_images,
    figsize=(12, 3),
    #gridspec_kw={'hspace': -0.4}
    )
for row, key in enumerate(path_to_images_collector.keys()):
    if row == 0:
        # Plot images from key 0 in the first row
        for img_idx in range(total_images):
            axes[0, img_idx].imshow(path_to_images_collector[key][img_idx])
            axes[0, img_idx].axis('off')  # Turn off axis labels
            axes[0, img_idx].set_title(f"Image {img_idx + 1}")
    else:
        # Plot images from key 1 in the second row
        for img_idx in range(total_images):
            axes[row, img_idx].imshow(path_to_images_collector[key][img_idx])
            axes[row, img_idx].axis('off')  # Turn off axis labels
    # Add a space between rows
    #plt.subplots_adjust(hspace=0.1)

# Adjust the spacing to reduce the gap between rows
plt.subplots_adjust(wspace=-1,)

plt.tight_layout()
output_pdf_path = f"groups.pdf"
plt.savefig(output_pdf_path, bbox_inches='tight')
plt.show()

# %%
num_images = 2
new_path_to_images_collector = {0:[], 1:[]}
for row_key in range(num_images):
    if row_key == 0:
        for key in [0,1,2]:
            new_path_to_images_collector[row_key].append(path_to_images_collector[i])
    else:
        for key in [3,4,5]:
            new_path_to_images_collector[row_key].append(path_to_images_collector[i])

# %%
new_path_to_images_collector
# Out:
# {0: ['log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#   'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#   'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3920.png'],
#  1: ['log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#   'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#   'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3920.png']}

# %%
path_to_images_collector
# Out:
# {0: 'log/runs/2024-09-05-23-59-47/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#  1: 'log/runs/2024-09-06-00-40-50/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#  2: 'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#  3: 'log/runs/2024-09-05-23-59-47/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#  4: 'log/runs/2024-09-06-00-40-50/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#  5: 'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3920.png'}

# %%
num_images
# Out:
# 2

# %%
path_to_images_collector
# Out:
# {0: 'log/runs/2024-09-05-23-59-47/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#  1: 'log/runs/2024-09-06-00-40-50/images/epoch_best/reconstructed/0/pergroup/image_3920.png',
#  2: 'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3920.png'}

# %%
total_images
# Out:
# 5

# %%
path_to_images_collector
# Out:
# {0: array(['log/runs/2024-09-06-00-40-50/images/epoch_best/reconstructed/0/pergroup/image_392.png',
#         'log/runs/2024-09-06-00-40-50/images/epoch_best/reconstructed/0/pergroup/image_1176.png',
#         'log/runs/2024-09-06-00-40-50/images/epoch_best/reconstructed/0/pergroup/image_1960.png',
#         'log/runs/2024-09-06-00-40-50/images/epoch_best/reconstructed/0/pergroup/image_2744.png',
#         'log/runs/2024-09-06-00-40-50/images/epoch_best/reconstructed/0/pergroup/image_3528.png'],
#        dtype='<U86'),
#  1: array(['log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_392.png',
#         'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_1176.png',
#         'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_1960.png',
#         'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_2744.png',
#         'log/runs/2024-09-06-01-18-43/images/epoch_best/reconstructed/0/pergroup/image_3528.png'],
#        dtype='<U86'),
#  2: array(['log/runs/2024-09-05-23-59-47/images/epoch_best/reconstructed/0/pergroup/image_392.png',
#         'log/runs/2024-09-05-23-59-47/images/epoch_best/reconstructed/0/pergroup/image_1176.png',
#         'log/runs/2024-09-05-23-59-47/images/epoch_best/reconstructed/0/pergroup/image_1960.png',
#         'log/runs/2024-09-05-23-59-47/images/epoch_best/reconstructed/0/pergroup/image_2744.png',
#         'log/runs/2024-09-05-23-59-47/images/epoch_best/reconstructed/0/pergroup/image_3528.png'],
#        dtype='<U86')}

# %%
path_to_images_collector[0][img_idx]
# Out:
# 'log/runs/2024-09-06-00-40-50/images/epoch_best/reconstructed/0/pergroup/image_1176.png'

# %%
filter_conditions
# Out:
# {0: {'TCR': {'train_snr_db': ['random'],
#    'train_classifier_separetely': [False],
#    'Elements compression': [31.0],
#    'compressor.use_trace_loss': [False]}},
#  1: {'TCR': {'train_snr_db': ['random'],
#    'train_classifier_separetely': [False],
#    'Elements compression': [88.0],
#    'compressor.use_trace_loss': [False]}},
#  2: {'TACR': {'train_snr_db': ['random'],
#    'train_classifier_separetely': [False],
#    'Elements compression': [40.0],
#    'compressor.use_trace_loss': [False]}}}

# %%
filter_conditions
# Out:
# {0: {'TCR': {'train_snr_db': ['random'],
#    'train_classifier_separetely': [False],
#    'Elements compression': [31.0],
#    'compressor.use_trace_loss': [False]}},
#  1: {'TCR': {'train_snr_db': ['random'],
#    'train_classifier_separetely': [False],
#    'Elements compression': [88.0],
#    'compressor.use_trace_loss': [False]}},
#  2: {'TACR': {'train_snr_db': ['random'],
#    'train_classifier_separetely': [False],
#    'Elements compression': [40.0],
#    'compressor.use_trace_loss': [False]}}}

# %%
path_to_images = os.path.join(subset['path'].item(), 'images/epoch_best/reconstructed/0/pergroup')

# %%
paths_to_images = glob.glob(path_to_images+'/*.png')

# %%
path_to_images_collector
# Out:
# {0: [], 1: []}

# %%
path_to_images_collector
# Out:
# {0: [<PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>,
#   <PIL.Image.Image image mode=RGB size=500x500>],
#  1: []}

# %%
unique_combinations_collector
# Out:
#    compressor.encoding_dim compressor.name  train_classifier_separetely  \
# 11                   135.0          ACRVIT                        False
# 27                    58.0          ACRVIT                        False
# 37                      NA           TCVIT                        False
# 41                      NA           TCVIT                        False
# 42                      NA           TCVIT                        False
# 43                      NA           TCVIT                        False
# 24                      NA          TCRVIT                        False
# 26                      NA          TCRVIT                        False
# 29                      NA          TCRVIT                        False
#
#    train_snr_db  Elements compression compressor.use_trace_loss  \
# 11            0                  30.0                        NA
# 27            0                  70.0                        NA
# 37            0                   0.0                     False
# 41            0                  95.0                     False
# 42            0                  88.0                     False
# 43            0                  15.0                     False
# 24            0                  95.0                      True
# 26            0                  88.0                      True
# 29            0                  15.0                      True
#
#                 compressor.r
# 11                        NA
# 27                        NA
# 37        [0, 0, 0, 0, 0, 0]
# 41  [40, 40, 40, 40, 40, 40]
# 42  [30, 30, 30, 30, 30, 30]
# 43        [5, 5, 5, 5, 5, 5]
# 24  [40, 40, 40, 40, 40, 40]
# 26  [30, 30, 30, 30, 30, 30]
# 29        [5, 5, 5, 5, 5, 5]

# %%
# Out:
# 30    TCVIT
# 32    TCVIT
# 36    TCVIT
# 37    TCVIT
# 38    TCVIT
# 39    TCVIT
# 40    TCVIT
# 41    TCVIT
# 42    TCVIT
# 43    TCVIT
# Name: compressor.name, dtype: object

# %%
df[df['compressor.name'] == 'TCRVIT']['compressor.r']
# Out:
# 1    [10, 10, 10, 10, 10, 10]
# 2          [5, 5, 5, 5, 5, 5]
# Name: compressor.r, dtype: object

# %%
mask
# Out:
# array([False, False, False, False, False])

# %%
subset['path']
# Out:
# Series([], Name: path, dtype: object)

# %%
snr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 snr
#
# NameError: name 'snr' is not defined

# %%
results
# Out:
# defaultdict(dict, {})

# %%
unique_combinations_collector
# Out:
# Empty DataFrame
# Columns: [compressor.encoding_dim, compressor.name, train_classifier_separetely, train_snr_db, Elements compression, compressor.use_trace_loss, compressor.r]
# Index: []

# %% [markdown]
# ### Table

# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Shared and personalized sweep columns
shared_sweep_columns = [
    'compressor.name', 
    'train_classifier_separetely', 
    'train_snr_db', 
    'Elements compression'
]

personalised_sweep_columns = {
    'ACRVIT': ['compressor.encoding_dim'] + shared_sweep_columns,
    'TVIT': ['compressor.use_trace_loss', 'compressor.r'] + shared_sweep_columns,
    'PCAVIT': ['compressor.q'] + shared_sweep_columns,
    'VIT': shared_sweep_columns
}

# Filter conditions for each model
filter_conditions = {
    0: {
       
        'TVIT': {
            'train_snr_db': [0, 'random'], 
            'train_classifier_separetely': [False], 
            #'Elements compression': [15., 31.,66., 88., 95.], 
            'compressor.use_trace_loss': [True, False]
        },
       
        },
    1: {
        'ACRVIT': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [70, 40, 10]
        },
        'TVIT': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [15., 31., 88., 95.], 
            'compressor.use_trace_loss': [True]
        },
        'VIT': {
            'train_snr_db': ['random'], 
            'train_classifier_separetely': [False], 
            'Elements compression': [0]
        }},
    2: {
        # 'ACRVIT': {
        #     'train_snr_db': [0], 
        #     'train_classifier_separetely': [False], 
        #     'Elements compression': [70, 40, 10]
        # },
        'TVIT': {
            'train_snr_db': ['random', 0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [ 15,  88.],  # 88., 95.
            'compressor.use_trace_loss': [True, False]
        },
        
        'VIT': {
            'train_snr_db': [0], 
            'train_classifier_separetely': [False], 
            'Elements compression': [0]
        }},
}


df_copy = df.copy()

num_plots = 1

for ax_idx in range(num_plots):
    ax = axs[ax_idx]

    unique_combinations_collector = pd.DataFrame()
    ax_fc = filter_conditions[ax_idx]
    for compressor_name in ax_fc.keys():
        compressor_df = df.loc[df['compressor.name'] == compressor_name]
        sweep_columns = personalised_sweep_columns[compressor_name]
        unique_combinations = compressor_df[sweep_columns].drop_duplicates()

        # Filter according to conditions
        for condition, values in ax_fc[compressor_name].items():
            unique_combinations = unique_combinations.loc[unique_combinations[condition].isin(values)]

        unique_combinations_collector = pd.concat([unique_combinations_collector, unique_combinations])
    
    # def update_name(row):
    #     if row['compressor.use_trace_loss']==False and row['compressor.name'] == 'TVIT':
    #         return 'No Trace Loss'
    #     return 'Trace Loss'
    # Apply the function to the DataFrame
    #unique_combinations_collector['compressor.name'] = unique_combinations_collector.apply(update_name, axis=1)
    #df_copy['compressor.name'] = df_copy.apply(update_name, axis=1)

    # Assign unique colors for each combination
    colors = plt.cm.tab10(np.linspace(0, 1, len(unique_combinations_collector) + 1))
    
    #color_dict = {idx: colors[i] for i, idx in enumerate(unique_combinations_collector.sort_values(by=['Elements compression', 'compressor.name']).index)}

    unique_combinations_collector.fillna('NA', inplace=True)

    unique_combinations_collector[unique_combinations_collector['compressor.name'].isin(['TVIT'])]


snr_vals_to_keep = [-10, 0, 10]
new_df = []
for idx, combination in unique_combinations_collector.iterrows():
    selected_idx = [df_copy[key] == val for key, val in combination.items()]
    mask = np.logical_and.reduce(selected_idx)
    subset = df_copy[mask]
    path_to_json = os.path.join(subset['path'].item(), 'results.json')

    # Load and plot results
    with open(path_to_json, 'r') as f:
        results = json.load(f)

    snr = np.array(list(results.keys())).astype(float)
    accuracy = np.array([results[key]['test/accuracy'] * 100 for key in results.keys()]).round(2)

   
    new_df.append({
                'snr': 'Average', 
                'accuracy_mean': np.round(accuracy.mean(),2),
                'accuracy_std': np.round(accuracy.std(),2), #f'{accuracy.mean()} ± {accuracy.std()}', 
                'compressor.name': combination['compressor.name'], 
                'compressor.use_trace_loss': combination['compressor.use_trace_loss'],
                'Elements compression': combination['Elements compression'],  # Add a comma here
                'train_snr_db': 'Noise' if combination['train_snr_db']=='random' else 'NoNoise',
            })
    
    # for s,acc in zip(snr, accuracy):
        # if s in snr_vals_to_keep:
        #     new_df.append({
        #         'snr': s, 
        #         'accuracy': acc, 
        #         'compressor.name': combination['compressor.name'], 
        #         'compressor.use_trace_loss': combination['compressor.use_trace_loss'],
        #         'Elements compression': combination['Elements compression'],  # Add a comma here
        #         'train_snr_db': 'Noise' if combination['train_snr_db']=='random' else 'NoNoise',
        #     })

new_df = pd.DataFrame(new_df)
#new_df['accuracy'] = new_df['accuracy_mean'].astype(str) + ' ± ' + new_df['accuracy_std'].astype(str)

#Create a pivot table and consider to have accuracy_mean +- accuracy_std
pivot_df_mean = new_df.pivot_table(
    index=['Elements compression'], 
    columns=['train_snr_db', 'compressor.use_trace_loss'], 
    values='accuracy_mean'
)

pivot_df_std = new_df.pivot_table(
    index=['Elements compression', 'snr'], 
    columns=['train_snr_db', 'compressor.name'], 
    values='accuracy_std'
)




# # Create a pivot table
# pivot_df = new_df.pivot_table(
#     index=['Elements compression', 'snr'], 
#     columns=['train_snr_db', 'compressor.name'], 
#     values='accuracy'
# )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 152
#     148 new_df = pd.DataFrame(new_df)
#     149 #new_df['accuracy'] = new_df['accuracy_mean'].astype(str) + ' ± ' + new_df['accuracy_std'].astype(str)
#     150
#     151 #Create a pivot table and consider to have accuracy_mean +- accuracy_std
# --> 152 pivot_df_mean = new_df.pivot_table(
#     153     index=['Elements compression'],
#     154     columns=['train_snr_db', 'compressor.use_trace_loss'],
#     155     values='accuracy_mean'
#     156 )
#     158 pivot_df_std = new_df.pivot_table(
#     159     index=['Elements compression', 'snr'],
#     160     columns=['train_snr_db', 'compressor.name'],
#     161     values='accuracy_std'
#     162 )
#     167 # # Create a pivot table
#     168 # pivot_df = new_df.pivot_table(
#     169 #     index=['Elements compression', 'snr'],
#     170 #     columns=['train_snr_db', 'compressor.name'],
#     171 #     values='accuracy'
#     172 # )
#
# File ~/miniconda3/envs/peekvit/lib/python3.11/site-packages/pandas/core/frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
#    9517         dropna=dropna,
#    9518         margins_name=margins_name,
#    9519         observed=observed,
#    9520         sort=sort,
#    9521     )
#
# File ~/miniconda3/envs/peekvit/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File ~/miniconda3/envs/peekvit/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'accuracy_mean'

# %%
# Out:
#    compressor.use_trace_loss              compressor.r  \
# 25                     False        [0, 0, 0, 0, 0, 0]
# 29                        NA                        NA
# 97                     False        [5, 5, 5, 5, 5, 5]
# 86                     False  [10, 10, 10, 10, 10, 10]
# 41                      True        [5, 5, 5, 5, 5, 5]
# 53                        NA                        NA
# 96                     False  [30, 30, 30, 30, 30, 30]
#
#     compressor.encoding_dim compressor.name  train_classifier_separetely  \
# 25                      192              VC                        False
# 29                      163              AC                        False
# 97                      192              TC                        False
# 86                      192              TC                        False
# 41                      135             TAC                        False
# 53                       58              AC                        False
# 96                      192              TC                        False
#
#    train_snr_db  Elements compression
# 25            0                   0.0
# 29            0                  15.0
# 97            0                  15.0
# 86            0                  31.0
# 41            0                  40.0
# 53            0                  70.0
# 96            0                  88.0

# %%
# Out:
#    compressor.encoding_dim compressor.name  train_classifier_separetely  \
# 0                    192.0           AEVIT                        False
# 1                    192.0           AEVIT                        False
# 2                    173.0           AEVIT                        False
# 4                    173.0           AEVIT                        False
# 6                    154.0           AEVIT                        False
# 8                    154.0           AEVIT                        False
# 10                   135.0           AEVIT                        False
# 11                   135.0           AEVIT                        False
# 13                   116.0           AEVIT                        False
# 15                   116.0           AEVIT                        False
# 17                    96.0           AEVIT                        False
# 19                    96.0           AEVIT                        False
# 21                    77.0           AEVIT                        False
# 23                    77.0           AEVIT                        False
# 25                    58.0           AEVIT                        False
# 27                    58.0           AEVIT                        False
# 41                      NA           TCVIT                        False
# 42                      NA           TCVIT                        False
# 43                      NA           TCVIT                        False
# 24                      NA          TCRVIT                        False
# 26                      NA          TCRVIT                        False
# 29                      NA          TCRVIT                        False
#
#    train_snr_db  Elements compression compressor.use_trace_loss  \
# 0        random                   0.0                        NA
# 1             0                   0.0                        NA
# 2        random                  10.0                        NA
# 4             0                  10.0                        NA
# 6        random                  20.0                        NA
# 8             0                  20.0                        NA
# 10       random                  30.0                        NA
# 11            0                  30.0                        NA
# 13       random                  40.0                        NA
# 15            0                  40.0                        NA
# 17       random                  50.0                        NA
# 19            0                  50.0                        NA
# 21       random                  60.0                        NA
# 23            0                  60.0                        NA
# 25       random                  70.0                        NA
# 27            0                  70.0                        NA
# 41            0                  95.0                     False
# 42            0                  88.0                     False
# 43            0                  15.0                     False
# 24            0                  95.0                      True
# 26            0                  88.0                      True
# 29            0                  15.0                      True
#
#                 compressor.r
# 0                         NA
# 1                         NA
# 2                         NA
# 4                         NA
# 6                         NA
# 8                         NA
# 10                        NA
# 11                        NA
# 13                        NA
# 15                        NA
# 17                        NA
# 19                        NA
# 21                        NA
# 23                        NA
# 25                        NA
# 27                        NA
# 41  [40, 40, 40, 40, 40, 40]
# 42  [30, 30, 30, 30, 30, 30]
# 43        [5, 5, 5, 5, 5, 5]
# 24  [40, 40, 40, 40, 40, 40]
# 26  [30, 30, 30, 30, 30, 30]
# 29        [5, 5, 5, 5, 5, 5]

# %%
selected_idx[0]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# Name: compressor.encoding_dim, dtype: bool

# %%
df['experiments_dir']
# Out:
# 0    log/runs/
# 1    log/runs/
# 2    log/runs/
# 3    log/runs/
# 4    log/runs/
# 5    log/runs/
# 6    log/runs/
# Name: experiments_dir, dtype: object

# %%
# Data frame from list of dictionaries

# %%
# read this /home/lev/projects_6g/peekvit/log/runs/2024-09-07-19-20-07/results.json

# Load and plot results
with open('/home/lev/projects_6g/peekvit/log/runs/2024-09-07-19-20-07/results.json', 'r') as f:
    results = json.load(f)

# %%
[10.48, 12.60, 12.84, 10.98, 11.86, 12.73]
# Out:
# {'-10': {'test/mse': nan,
#   'test/classification_loss': 0.5922406335030833,
#   'test/accuracy': 0.8282802700996399,
#   'test/loss': nan},
#  '-9': {'test/mse': nan,
#   'test/classification_loss': 0.5798860942163775,
#   'test/accuracy': 0.831337571144104,
#   'test/loss': nan},
#  '-8': {'test/mse': nan,
#   'test/classification_loss': 0.5776211254058345,
#   'test/accuracy': 0.8397452235221863,
#   'test/loss': nan},
#  '-7': {'test/mse': nan,
#   'test/classification_loss': 0.5708080914712721,
#   'test/accuracy': 0.8453503251075745,
#   'test/loss': nan},
#  '-6': {'test/mse': nan,
#   'test/classification_loss': 0.5802927805531409,
#   'test/accuracy': 0.8428025245666504,
#   'test/loss': nan},
#  '-5': {'test/mse': nan,
#   'test/classification_loss': 0.5766821196002345,
#   'test/accuracy': 0.8478980660438538,
#   'test/loss': nan},
#  '-4': {'test/mse': nan,
#   'test/classification_loss': 0.5913747991285017,
#   'test/accuracy': 0.8484076261520386,
#   'test/loss': nan},
#  '-3': {'test/mse': nan,
#   'test/classification_loss': 0.5806125508200738,
#   'test/accuracy': 0.8529936075210571,
#   'test/loss': nan},
#  '-2': {'test/mse': nan,
#   'test/classification_loss': 0.5947022111185135,
#   'test/accuracy': 0.8519745469093323,
#   'test/loss': nan},
#  '-1': {'test/mse': nan,
#   'test/classification_loss': 0.5955607915116895,
#   'test/accuracy': 0.8532484173774719,
#   'test/loss': nan},
#  '0': {'test/mse': nan,
#   'test/classification_loss': 0.6004559051605963,
#   'test/accuracy': 0.8517197370529175,
#   'test/loss': nan},
#  '1': {'test/mse': nan,
#   'test/classification_loss': 0.603942524040899,
#   'test/accuracy': 0.8537579774856567,
#   'test/loss': nan},
#  '2': {'test/mse': nan,
#   'test/classification_loss': 0.6023274294791683,
#   'test/accuracy': 0.8555414080619812,
#   'test/loss': nan},
#  '3': {'test/mse': nan,
#   'test/classification_loss': 0.6017524638483601,
#   'test/accuracy': 0.8529936075210571,
#   'test/loss': nan},
#  '4': {'test/mse': nan,
#   'test/classification_loss': 0.6079906066579204,
#   'test/accuracy': 0.8532484173774719,
#   'test/loss': nan},
#  '5': {'test/mse': nan,
#   'test/classification_loss': 0.6118223167234852,
#   'test/accuracy': 0.8547770977020264,
#   'test/loss': nan},
#  '6': {'test/mse': nan,
#   'test/classification_loss': 0.61253222823143,
#   'test/accuracy': 0.8547770977020264,
#   'test/loss': nan},
#  '7': {'test/mse': nan,
#   'test/classification_loss': 0.6144606081708786,
#   'test/accuracy': 0.8557961583137512,
#   'test/loss': nan},
#  '8': {'test/mse': nan,
#   'test/classification_loss': 0.6110092680300435,
#   'test/accuracy': 0.8570700883865356,
#   'test/loss': nan},
#  '9': {'test/mse': nan,
#   'test/classification_loss': 0.6139407181932081,
#   'test/accuracy': 0.856305718421936,
#   'test/loss': nan},
#  '10': {'test/mse': nan,
#   'test/classification_loss': 0.6120848434586679,
#   'test/accuracy': 0.8557961583137512,
#   'test/loss': nan}}
